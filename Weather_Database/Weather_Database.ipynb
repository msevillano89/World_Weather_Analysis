# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np

# Import citypy
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the API key.
from config import g_key
from config import weather_api_key

# Import Collections
import collections.abc
# Adjust aliases to be done manually.
collections.Iterable = collections.abc.Iterable
collections.Mapping = collections.abc.Mapping
collections.MutableSet = collections.abc.MutableSet
collections.MutableMapping = collections.abc.MutableMapping

# %% [markdown]
# ### Create 2,000 random latitudes and longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unpack zip of latitudes and longitudes file into a list
coordinates = list(lat_lngs)

# %% [markdown]
# ### Generate city list based on random coordinates generated from above

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %% [markdown]
# ### Make API Call and retrieve weather data

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sabha
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | namibe
# Processing Record 5 of Set 1 | port lincoln
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | caconda
# Processing Record 8 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | grand gaube
# Processing Record 11 of Set 1 | bell ville
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | lompoc
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | yei
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | coquimbo
# Processing Record 21 of Set 1 | verkhniye sergi
# Processing Record 22 of Set 1 | chabahar
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | dingle
# Processing Record 26 of Set 1 | sao filipe
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | roma
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | san juan
# Processing Record 42 of Set 1 | constitucion
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | tugalan
# City not found. Skipping...
# Processing Record 47 of Set 1 | timmins
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | huarmey
# Processing Record 1 of Set 2 | khorinsk
# Processing Record 2 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 2 | livingstonia
# Processing Record 4 of Set 2 | lavrentiya
# Processing Record 5 of Set 2 | tuatapere
# Processing Record 6 of Set 2 | geraldton
# Processing Record 7 of Set 2 | ndjole
# Processing Record 8 of Set 2 | norman wells
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | shimanovsk
# Processing Record 13 of Set 2 | katsuura
# Processing Record 14 of Set 2 | omboue
# Processing Record 15 of Set 2 | slave lake
# Processing Record 16 of Set 2 | padang
# Processing Record 17 of Set 2 | manjeshwar
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | ushtobe
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | novobiryusinskiy
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | tawang
# Processing Record 26 of Set 2 | kidal
# Processing Record 27 of Set 2 | baherden
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | baykit
# Processing Record 31 of Set 2 | moulmeingyun
# City not found. Skipping...
# Processing Record 32 of Set 2 | vaitape
# Processing Record 33 of Set 2 | yining
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | saryagash
# Processing Record 37 of Set 2 | flinders
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | bayir
# Processing Record 44 of Set 2 | koumac
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | fortuna
# Processing Record 47 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 2 | san patricio
# Processing Record 49 of Set 2 | lagoa
# Processing Record 50 of Set 2 | tazovskiy
# Processing Record 1 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | punta arenas
# Processing Record 4 of Set 3 | itoman
# Processing Record 5 of Set 3 | megion
# Processing Record 6 of Set 3 | orbetello
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | rameswaram
# Processing Record 12 of Set 3 | madras
# Processing Record 13 of Set 3 | salinas
# Processing Record 14 of Set 3 | kiama
# Processing Record 15 of Set 3 | linxia
# Processing Record 16 of Set 3 | college
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | katobu
# Processing Record 19 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 21 of Set 3 | aguimes
# Processing Record 22 of Set 3 | launceston
# Processing Record 23 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 3 | aksay
# Processing Record 25 of Set 3 | buritis
# Processing Record 26 of Set 3 | egvekinot
# Processing Record 27 of Set 3 | luau
# Processing Record 28 of Set 3 | barinas
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | galle
# Processing Record 32 of Set 3 | vila velha
# Processing Record 33 of Set 3 | havoysund
# Processing Record 34 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 3 | marsa matruh
# Processing Record 36 of Set 3 | gravdal
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | hay river
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | heihe
# Processing Record 41 of Set 3 | makakilo city
# Processing Record 42 of Set 3 | sakakah
# Processing Record 43 of Set 3 | moron
# Processing Record 44 of Set 3 | aksu
# Processing Record 45 of Set 3 | kysyl-syr
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | ambilobe
# Processing Record 48 of Set 3 | bubaque
# Processing Record 49 of Set 3 | muravlenko
# Processing Record 50 of Set 3 | narsaq
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | zhukovka
# Processing Record 3 of Set 4 | lourdes
# Processing Record 4 of Set 4 | dhidhdhoo
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | doha
# Processing Record 7 of Set 4 | samarai
# Processing Record 8 of Set 4 | charters towers
# Processing Record 9 of Set 4 | sur
# Processing Record 10 of Set 4 | svetlyy
# Processing Record 11 of Set 4 | pathein
# Processing Record 12 of Set 4 | taperoa
# Processing Record 13 of Set 4 | eureka
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | salinopolis
# Processing Record 16 of Set 4 | lazaro cardenas
# Processing Record 17 of Set 4 | sorsk
# Processing Record 18 of Set 4 | fernandina beach
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | nabire
# Processing Record 21 of Set 4 | komsomolskiy
# Processing Record 22 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 4 | nome
# Processing Record 24 of Set 4 | nikolskoye
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | haines junction
# Processing Record 27 of Set 4 | skibotn
# Processing Record 28 of Set 4 | port-gentil
# Processing Record 29 of Set 4 | sambava
# Processing Record 30 of Set 4 | saurimo
# Processing Record 31 of Set 4 | tura
# Processing Record 32 of Set 4 | road town
# Processing Record 33 of Set 4 | hualmay
# Processing Record 34 of Set 4 | lingao
# Processing Record 35 of Set 4 | itamaraju
# Processing Record 36 of Set 4 | den helder
# Processing Record 37 of Set 4 | erzin
# Processing Record 38 of Set 4 | zhigansk
# Processing Record 39 of Set 4 | upernavik
# Processing Record 40 of Set 4 | praia
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | sao jose da coroa grande
# Processing Record 43 of Set 4 | mbalmayo
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 4 | genhe
# Processing Record 47 of Set 4 | nuuk
# Processing Record 48 of Set 4 | zholymbet
# Processing Record 49 of Set 4 | birao
# Processing Record 50 of Set 4 | nyahururu
# Processing Record 1 of Set 5 | isangel
# Processing Record 2 of Set 5 | belgrade
# Processing Record 3 of Set 5 | beira
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | srandakan
# Processing Record 6 of Set 5 | ulaangom
# Processing Record 7 of Set 5 | vila franca do campo
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | hilo
# Processing Record 10 of Set 5 | riwaka
# Processing Record 11 of Set 5 | batemans bay
# Processing Record 12 of Set 5 | butaritari
# Processing Record 13 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 5 | otjiwarongo
# Processing Record 16 of Set 5 | san carlos de bariloche
# Processing Record 17 of Set 5 | iralaya
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 5 | wynyard
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | bayan
# Processing Record 23 of Set 5 | ixtapa
# Processing Record 24 of Set 5 | pinkafeld
# Processing Record 25 of Set 5 | pacific grove
# Processing Record 26 of Set 5 | binzhou
# Processing Record 27 of Set 5 | vicuna
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | aleksandrov gay
# Processing Record 30 of Set 5 | laguna
# Processing Record 31 of Set 5 | oktyabrskoye
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | nalut
# Processing Record 34 of Set 5 | pevek
# Processing Record 35 of Set 5 | plettenberg bay
# Processing Record 36 of Set 5 | coihaique
# Processing Record 37 of Set 5 | piacabucu
# Processing Record 38 of Set 5 | lang son
# Processing Record 39 of Set 5 | hasaki
# Processing Record 40 of Set 5 | bonavista
# Processing Record 41 of Set 5 | yate
# Processing Record 42 of Set 5 | ibra
# Processing Record 43 of Set 5 | niamey
# Processing Record 44 of Set 5 | artyom
# Processing Record 45 of Set 5 | shamary
# Processing Record 46 of Set 5 | voyvozh
# Processing Record 47 of Set 5 | yeppoon
# Processing Record 48 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 5 | hamilton
# Processing Record 50 of Set 5 | aripuana
# Processing Record 1 of Set 6 | codrington
# Processing Record 2 of Set 6 | sorong
# Processing Record 3 of Set 6 | qui nhon
# Processing Record 4 of Set 6 | san carlos
# Processing Record 5 of Set 6 | rognan
# Processing Record 6 of Set 6 | melfi
# Processing Record 7 of Set 6 | goba
# Processing Record 8 of Set 6 | grants pass
# Processing Record 9 of Set 6 | vestmanna
# Processing Record 10 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 6 | rawson
# Processing Record 12 of Set 6 | bacolod
# Processing Record 13 of Set 6 | berbera
# Processing Record 14 of Set 6 | iqaluit
# Processing Record 15 of Set 6 | kruisfontein
# Processing Record 16 of Set 6 | sorland
# Processing Record 17 of Set 6 | vanimo
# Processing Record 18 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | ahipara
# Processing Record 20 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 21 of Set 6 | utevka
# Processing Record 22 of Set 6 | missoula
# Processing Record 23 of Set 6 | dongsheng
# Processing Record 24 of Set 6 | kuah
# Processing Record 25 of Set 6 | faisalabad
# Processing Record 26 of Set 6 | champerico
# Processing Record 27 of Set 6 | porterville
# Processing Record 28 of Set 6 | buala
# Processing Record 29 of Set 6 | airai
# Processing Record 30 of Set 6 | gunjur
# Processing Record 31 of Set 6 | kaitangata
# Processing Record 32 of Set 6 | belyy yar
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | bjornevatn
# Processing Record 35 of Set 6 | avera
# Processing Record 36 of Set 6 | kuytun
# Processing Record 37 of Set 6 | ponta do sol
# Processing Record 38 of Set 6 | talara
# Processing Record 39 of Set 6 | flin flon
# Processing Record 40 of Set 6 | camacari
# Processing Record 41 of Set 6 | baoqing
# Processing Record 42 of Set 6 | necochea
# Processing Record 43 of Set 6 | leningradskiy
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | teya
# Processing Record 46 of Set 6 | tignere
# Processing Record 47 of Set 6 | deputatskiy
# Processing Record 48 of Set 6 | port moresby
# Processing Record 49 of Set 6 | muromtsevo
# Processing Record 50 of Set 6 | ostersund
# Processing Record 1 of Set 7 | oranjemund
# Processing Record 2 of Set 7 | shimoda
# Processing Record 3 of Set 7 | rorvik
# Processing Record 4 of Set 7 | srednekolymsk
# Processing Record 5 of Set 7 | khabary
# Processing Record 6 of Set 7 | labuhan
# Processing Record 7 of Set 7 | arraial do cabo
# Processing Record 8 of Set 7 | te anau
# Processing Record 9 of Set 7 | vardo
# Processing Record 10 of Set 7 | viedma
# Processing Record 11 of Set 7 | ribeira grande
# Processing Record 12 of Set 7 | bilibino
# Processing Record 13 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 7 | ishigaki
# Processing Record 15 of Set 7 | harper
# Processing Record 16 of Set 7 | senneterre
# Processing Record 17 of Set 7 | dwarka
# Processing Record 18 of Set 7 | hofn
# Processing Record 19 of Set 7 | kenora
# Processing Record 20 of Set 7 | escanaba
# Processing Record 21 of Set 7 | pinawa
# Processing Record 22 of Set 7 | torrington
# Processing Record 23 of Set 7 | chuy
# Processing Record 24 of Set 7 | mount isa
# Processing Record 25 of Set 7 | liwale
# Processing Record 26 of Set 7 | locri
# Processing Record 27 of Set 7 | loa janan
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | payo
# Processing Record 30 of Set 7 | hare bay
# Processing Record 31 of Set 7 | roald
# Processing Record 32 of Set 7 | middelburg
# Processing Record 33 of Set 7 | east london
# Processing Record 34 of Set 7 | catalina
# Processing Record 35 of Set 7 | ingraj bazar
# Processing Record 36 of Set 7 | pangnirtung
# Processing Record 37 of Set 7 | conceicao do araguaia
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | le port
# Processing Record 40 of Set 7 | cherepanovo
# Processing Record 41 of Set 7 | coahuayana
# Processing Record 42 of Set 7 | seoul
# Processing Record 43 of Set 7 | bilma
# Processing Record 44 of Set 7 | elizabeth city
# Processing Record 45 of Set 7 | araguacu
# Processing Record 46 of Set 7 | vadso
# Processing Record 47 of Set 7 | mahajanga
# Processing Record 48 of Set 7 | porto velho
# Processing Record 49 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 50 of Set 7 | mandla
# Processing Record 1 of Set 8 | orumiyeh
# Processing Record 2 of Set 8 | san quintin
# Processing Record 3 of Set 8 | dalby
# Processing Record 4 of Set 8 | ofaqim
# Processing Record 5 of Set 8 | vao
# Processing Record 6 of Set 8 | kenai
# Processing Record 7 of Set 8 | zhangye
# Processing Record 8 of Set 8 | luanda
# Processing Record 9 of Set 8 | novikovo
# Processing Record 10 of Set 8 | acin
# City not found. Skipping...
# Processing Record 11 of Set 8 | dunedin
# Processing Record 12 of Set 8 | los llanos de aridane
# Processing Record 13 of Set 8 | vysokogornyy
# Processing Record 14 of Set 8 | sarangani
# Processing Record 15 of Set 8 | sitka
# Processing Record 16 of Set 8 | saskylakh
# Processing Record 17 of Set 8 | iberia
# Processing Record 18 of Set 8 | yanam
# Processing Record 19 of Set 8 | vestmannaeyjar
# Processing Record 20 of Set 8 | colquechaca
# Processing Record 21 of Set 8 | santa rosa
# Processing Record 22 of Set 8 | korla
# Processing Record 23 of Set 8 | lac du bonnet
# Processing Record 24 of Set 8 | aklavik
# Processing Record 25 of Set 8 | broken hill
# Processing Record 26 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 8 | kimberley
# Processing Record 28 of Set 8 | itarema
# Processing Record 29 of Set 8 | hobyo
# Processing Record 30 of Set 8 | ambon
# Processing Record 31 of Set 8 | pingzhuang
# Processing Record 32 of Set 8 | xichang
# Processing Record 33 of Set 8 | nyurba
# Processing Record 34 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 8 | arsk
# Processing Record 36 of Set 8 | tautira
# Processing Record 37 of Set 8 | oltu
# Processing Record 38 of Set 8 | tramore
# Processing Record 39 of Set 8 | oyama
# Processing Record 40 of Set 8 | irbeyskoye
# Processing Record 41 of Set 8 | fevik
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | kajaani
# Processing Record 44 of Set 8 | bac can
# City not found. Skipping...
# Processing Record 45 of Set 8 | seminole
# Processing Record 46 of Set 8 | ponta delgada
# Processing Record 47 of Set 8 | ziro
# Processing Record 48 of Set 8 | mumias
# Processing Record 49 of Set 8 | pincher creek
# Processing Record 50 of Set 8 | quesnel
# Processing Record 1 of Set 9 | aketi
# Processing Record 2 of Set 9 | rincon
# Processing Record 3 of Set 9 | beyneu
# Processing Record 4 of Set 9 | kaduy
# Processing Record 5 of Set 9 | emba
# Processing Record 6 of Set 9 | jaroslaw
# Processing Record 7 of Set 9 | nemuro
# Processing Record 8 of Set 9 | novo aripuana
# Processing Record 9 of Set 9 | antofagasta
# Processing Record 10 of Set 9 | camargo
# Processing Record 11 of Set 9 | quelimane
# Processing Record 12 of Set 9 | cururupu
# Processing Record 13 of Set 9 | khatanga
# Processing Record 14 of Set 9 | kurilsk
# Processing Record 15 of Set 9 | qaqortoq
# Processing Record 16 of Set 9 | kraslava
# Processing Record 17 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 18 of Set 9 | pochutla
# Processing Record 19 of Set 9 | secunda
# Processing Record 20 of Set 9 | inhambane
# Processing Record 21 of Set 9 | smolenka
# Processing Record 22 of Set 9 | yarqa
# Processing Record 23 of Set 9 | karaton
# Processing Record 24 of Set 9 | taoudenni
# Processing Record 25 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 9 | santa cruz
# Processing Record 27 of Set 9 | mehamn
# Processing Record 28 of Set 9 | dekar
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 9 | minuri
# Processing Record 32 of Set 9 | wagar
# Processing Record 33 of Set 9 | balkhash
# Processing Record 34 of Set 9 | alugan
# Processing Record 35 of Set 9 | anito
# Processing Record 36 of Set 9 | berlevag
# Processing Record 37 of Set 9 | saint-pierre
# Processing Record 38 of Set 9 | lorengau
# Processing Record 39 of Set 9 | mirnyy
# Processing Record 40 of Set 9 | eyl
# Processing Record 41 of Set 9 | sept-iles
# Processing Record 42 of Set 9 | diffa
# Processing Record 43 of Set 9 | inirida
# Processing Record 44 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 45 of Set 9 | la asuncion
# Processing Record 46 of Set 9 | kupang
# Processing Record 47 of Set 9 | zakharovo
# Processing Record 48 of Set 9 | culipapa
# City not found. Skipping...
# Processing Record 49 of Set 9 | mocorito
# Processing Record 50 of Set 9 | rundu
# Processing Record 1 of Set 10 | may pen
# Processing Record 2 of Set 10 | yar-sale
# Processing Record 3 of Set 10 | kaka
# Processing Record 4 of Set 10 | jacksonville beach
# Processing Record 5 of Set 10 | evensk
# Processing Record 6 of Set 10 | buraydah
# Processing Record 7 of Set 10 | havre-saint-pierre
# Processing Record 8 of Set 10 | gunnedah
# Processing Record 9 of Set 10 | porto novo
# Processing Record 10 of Set 10 | itamaraca
# Processing Record 11 of Set 10 | guangyuan
# Processing Record 12 of Set 10 | lalin
# Processing Record 13 of Set 10 | rangapara
# Processing Record 14 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 15 of Set 10 | san cristobal
# Processing Record 16 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 10 | shakawe
# Processing Record 18 of Set 10 | elban
# Processing Record 19 of Set 10 | mingguang
# Processing Record 20 of Set 10 | doka
# Processing Record 21 of Set 10 | atikokan
# Processing Record 22 of Set 10 | hovd
# Processing Record 23 of Set 10 | santa maria
# Processing Record 24 of Set 10 | dezful
# Processing Record 25 of Set 10 | nouakchott
# Processing Record 26 of Set 10 | sibolga
# Processing Record 27 of Set 10 | orotukan
# Processing Record 28 of Set 10 | methoni
# Processing Record 29 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 30 of Set 10 | bud
# Processing Record 31 of Set 10 | camana
# Processing Record 32 of Set 10 | warud
# Processing Record 33 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 10 | fulacunda
# City not found. Skipping...
# Processing Record 35 of Set 10 | sao gabriel
# Processing Record 36 of Set 10 | altamira
# Processing Record 37 of Set 10 | chardara
# Processing Record 38 of Set 10 | manokwari
# Processing Record 39 of Set 10 | souillac
# Processing Record 40 of Set 10 | chicama
# Processing Record 41 of Set 10 | haapu
# City not found. Skipping...
# Processing Record 42 of Set 10 | tukan
# Processing Record 43 of Set 10 | zhanaozen
# Processing Record 44 of Set 10 | elat
# Processing Record 45 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 10 | marsh harbour
# Processing Record 47 of Set 10 | tawau
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | bossangoa
# Processing Record 50 of Set 10 | general roca
# Processing Record 1 of Set 11 | matara
# Processing Record 2 of Set 11 | mattawa
# Processing Record 3 of Set 11 | cockburn town
# Processing Record 4 of Set 11 | trincomalee
# Processing Record 5 of Set 11 | anadyr
# Processing Record 6 of Set 11 | tokur
# Processing Record 7 of Set 11 | killarney
# Processing Record 8 of Set 11 | tweed
# Processing Record 9 of Set 11 | koraput
# Processing Record 10 of Set 11 | merauke
# Processing Record 11 of Set 11 | khao yoi
# Processing Record 12 of Set 11 | cap malheureux
# Processing Record 13 of Set 11 | saldanha
# Processing Record 14 of Set 11 | frunzivka
# Processing Record 15 of Set 11 | ouesso
# Processing Record 16 of Set 11 | takoradi
# Processing Record 17 of Set 11 | gusau
# Processing Record 18 of Set 11 | george
# Processing Record 19 of Set 11 | araouane
# Processing Record 20 of Set 11 | miri
# Processing Record 21 of Set 11 | san rafael
# Processing Record 22 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 11 | zurrieq
# Processing Record 24 of Set 11 | dolores
# Processing Record 25 of Set 11 | vila do maio
# Processing Record 26 of Set 11 | asosa
# Processing Record 27 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 11 | caravelas
# Processing Record 29 of Set 11 | muscat
# Processing Record 30 of Set 11 | fasa
# Processing Record 31 of Set 11 | manzhouli
# Processing Record 32 of Set 11 | lowestoft
# Processing Record 33 of Set 11 | jilin
# Processing Record 34 of Set 11 | mata
# Processing Record 35 of Set 11 | poum
# Processing Record 36 of Set 11 | salalah
# Processing Record 37 of Set 11 | okha
# Processing Record 38 of Set 11 | tabou
# Processing Record 39 of Set 11 | ostrovnoy
# Processing Record 40 of Set 11 | high level
# Processing Record 41 of Set 11 | enterprise
# Processing Record 42 of Set 11 | yerkoy
# Processing Record 43 of Set 11 | itaituba
# Processing Record 44 of Set 11 | antalaha
# Processing Record 45 of Set 11 | bulawayo
# Processing Record 46 of Set 11 | kedrovyy
# Processing Record 47 of Set 11 | libreville
# Processing Record 48 of Set 11 | erenhot
# Processing Record 49 of Set 11 | grindavik
# Processing Record 50 of Set 11 | marienburg
# Processing Record 1 of Set 12 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 2 of Set 12 | santiago del estero
# Processing Record 3 of Set 12 | teguldet
# Processing Record 4 of Set 12 | atar
# Processing Record 5 of Set 12 | margate
# Processing Record 6 of Set 12 | magadi
# Processing Record 7 of Set 12 | massakory
# Processing Record 8 of Set 12 | tecoanapa
# Processing Record 9 of Set 12 | fukue
# Processing Record 10 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 12 | praia da vitoria
# Processing Record 12 of Set 12 | teguise
# Processing Record 13 of Set 12 | koshurnikovo
# Processing Record 14 of Set 12 | meulaboh
# Processing Record 15 of Set 12 | svetlogorsk
# Processing Record 16 of Set 12 | fort frances
# Processing Record 17 of Set 12 | nikki
# Processing Record 18 of Set 12 | lodwar
# Processing Record 19 of Set 12 | saint-leu
# Processing Record 20 of Set 12 | russell
# Processing Record 21 of Set 12 | rio grande
# Processing Record 22 of Set 12 | manicore
# Processing Record 23 of Set 12 | port augusta
# Processing Record 24 of Set 12 | waipawa
# Processing Record 25 of Set 12 | tamasopo
# Processing Record 26 of Set 12 | sovetskiy
# Processing Record 27 of Set 12 | natal
# Processing Record 28 of Set 12 | raudeberg
# Processing Record 29 of Set 12 | westport
# Processing Record 30 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 12 | shingu
# Processing Record 32 of Set 12 | puga
# Processing Record 33 of Set 12 | borlange
# City not found. Skipping...
# Processing Record 34 of Set 12 | gazion
# City not found. Skipping...
# Processing Record 35 of Set 12 | sabang
# Processing Record 36 of Set 12 | camacha
# Processing Record 37 of Set 12 | nsanje
# Processing Record 38 of Set 12 | burnie
# Processing Record 39 of Set 12 | aykhal
# Processing Record 40 of Set 12 | nyaunglebin
# Processing Record 41 of Set 12 | bodmin
# Processing Record 42 of Set 12 | opuwo
# Processing Record 43 of Set 12 | noumea
# Processing Record 44 of Set 12 | riyaq
# City not found. Skipping...
# Processing Record 45 of Set 12 | mayo
# Processing Record 46 of Set 12 | magistralnyy
# Processing Record 47 of Set 12 | adrar
# Processing Record 48 of Set 12 | verin
# Processing Record 49 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 12 | hassleholm
# Processing Record 1 of Set 13 | mogadishu
# Processing Record 2 of Set 13 | asau
# Processing Record 3 of Set 13 | atasu
# Processing Record 4 of Set 13 | kalomo
# City not found. Skipping...
# Processing Record 5 of Set 13 | tucurui
# Processing Record 6 of Set 13 | gummidipundi
# Processing Record 7 of Set 13 | inongo
# Processing Record 8 of Set 13 | la romana
# Processing Record 9 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 13 | pitiquito
# Processing Record 11 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 13 | amberley
# Processing Record 13 of Set 13 | shelburne
# Processing Record 14 of Set 13 | umm lajj
# Processing Record 15 of Set 13 | barcelos
# Processing Record 16 of Set 13 | high prairie
# Processing Record 17 of Set 13 | san ramon
# Processing Record 18 of Set 13 | khairpur nathan shah
# Processing Record 19 of Set 13 | ternate
# Processing Record 20 of Set 13 | sebastian
# Processing Record 21 of Set 13 | sawakin
# Processing Record 22 of Set 13 | north bend
# Processing Record 23 of Set 13 | barbacena
# Processing Record 24 of Set 13 | nata
# Processing Record 25 of Set 13 | altos del rosario
# Processing Record 26 of Set 13 | tipperary
# Processing Record 27 of Set 13 | seydi
# Processing Record 28 of Set 13 | marrakesh
# Processing Record 29 of Set 13 | beringovskiy
# Processing Record 30 of Set 13 | bukama
# Processing Record 31 of Set 13 | effingham
# Processing Record 32 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 34 of Set 13 | mana
# Processing Record 35 of Set 13 | sebring
# Processing Record 36 of Set 13 | ginda
# Processing Record 37 of Set 13 | mount gambier
# Processing Record 38 of Set 13 | andreapol
# Processing Record 39 of Set 13 | sarkand
# Processing Record 40 of Set 13 | salta
# Processing Record 41 of Set 13 | barranca
# Processing Record 42 of Set 13 | changji
# Processing Record 43 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 44 of Set 13 | ciudad bolivar
# Processing Record 45 of Set 13 | fuyu
# Processing Record 46 of Set 13 | kuching
# Processing Record 47 of Set 13 | hamadan
# Processing Record 48 of Set 13 | trairi
# Processing Record 49 of Set 13 | naantali
# Processing Record 50 of Set 13 | nantucket
# Processing Record 1 of Set 14 | half moon bay
# Processing Record 2 of Set 14 | san vicente
# Processing Record 3 of Set 14 | yarmouth
# Processing Record 4 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 5 of Set 14 | ewa beach
# Processing Record 6 of Set 14 | bull savanna
# Processing Record 7 of Set 14 | toyooka
# Processing Record 8 of Set 14 | batagay-alyta
# Processing Record 9 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 14 | watsa
# Processing Record 11 of Set 14 | bow island
# Processing Record 12 of Set 14 | pangani
# Processing Record 13 of Set 14 | hoi an
# Processing Record 14 of Set 14 | la antigua
# Processing Record 15 of Set 14 | prestea
# Processing Record 16 of Set 14 | terney
# Processing Record 17 of Set 14 | youkounkoun
# Processing Record 18 of Set 14 | puerto quijarro
# Processing Record 19 of Set 14 | la ronge
# Processing Record 20 of Set 14 | kisanga
# Processing Record 21 of Set 14 | richards bay
# Processing Record 22 of Set 14 | acapulco
# Processing Record 23 of Set 14 | tevaitoa
# Processing Record 24 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 14 | carmen
# Processing Record 26 of Set 14 | rio gallegos
# Processing Record 27 of Set 14 | cedeno
# Processing Record 28 of Set 14 | muncar
# Processing Record 29 of Set 14 | nola
# Processing Record 30 of Set 14 | carutapera
# Processing Record 31 of Set 14 | sehithwa
# Processing Record 32 of Set 14 | esperance
# Processing Record 33 of Set 14 | zhangjiakou
# Processing Record 34 of Set 14 | namatanai
# Processing Record 35 of Set 14 | altay
# Processing Record 36 of Set 14 | muros
# Processing Record 37 of Set 14 | new baltimore
# Processing Record 38 of Set 14 | clocolan
# Processing Record 39 of Set 14 | nueva florida
# Processing Record 40 of Set 14 | tivoli
# Processing Record 41 of Set 14 | chirongui
# Processing Record 42 of Set 14 | marquette
# Processing Record 43 of Set 14 | nelson bay
# Processing Record 44 of Set 14 | tondano
# Processing Record 45 of Set 14 | harrogate
# Processing Record 46 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 14 | olafsvik
# Processing Record 48 of Set 14 | mujiayingzi
# Processing Record 49 of Set 14 | turayf
# Processing Record 50 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 15 | inuvik
# Processing Record 2 of Set 15 | kuryk
# Processing Record 3 of Set 15 | pandan
# Processing Record 4 of Set 15 | marzuq
# Processing Record 5 of Set 15 | kobojango
# City not found. Skipping...
# Processing Record 6 of Set 15 | kabo
# Processing Record 7 of Set 15 | andenes
# Processing Record 8 of Set 15 | catamarca
# Processing Record 9 of Set 15 | guymon
# Processing Record 10 of Set 15 | zhuhai
# Processing Record 11 of Set 15 | alofi
# Processing Record 12 of Set 15 | bambanglipuro
# Processing Record 13 of Set 15 | kapuskasing
# Processing Record 14 of Set 15 | bejar
# Processing Record 15 of Set 15 | faya
# Processing Record 16 of Set 15 | kubuta
# Processing Record 17 of Set 15 | kempele
# Processing Record 18 of Set 15 | palmer
# Processing Record 19 of Set 15 | chany
# Processing Record 20 of Set 15 | katangli
# Processing Record 21 of Set 15 | pouebo
# Processing Record 22 of Set 15 | presidencia roque saenz pena
# Processing Record 23 of Set 15 | torres
# Processing Record 24 of Set 15 | cascais
# Processing Record 25 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 15 | karoi
# Processing Record 27 of Set 15 | hailar
# Processing Record 28 of Set 15 | maues
# Processing Record 29 of Set 15 | moissala
# Processing Record 30 of Set 15 | mahibadhoo
# Processing Record 31 of Set 15 | daura
# Processing Record 32 of Set 15 | khelyulya
# Processing Record 33 of Set 15 | ierapetra
# Processing Record 34 of Set 15 | priargunsk
# Processing Record 35 of Set 15 | pinega
# Processing Record 36 of Set 15 | bathsheba
# Processing Record 37 of Set 15 | kilifi
# Processing Record 38 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 15 | roswell
# Processing Record 40 of Set 15 | faro
# Processing Record 41 of Set 15 | ahuimanu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Create and export DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Sabha      LY  27.0377   14.4283     82.71        15           0
# 1        Atuona      PF  -9.8000 -139.0333     78.15        70          58
# 2    Chokurdakh      RU  70.6333  147.9167     48.51        50         100
# 3        Namibe      AO -15.1961   12.1522     61.65        89          15
# 4  Port Lincoln      AU -34.7333  135.8667     56.28        70         100
# 5        Torbay      CA  47.6666  -52.7314     62.28        80         100
# 6       Caconda      AO -13.7333   15.0667     55.42        43           4
# 7       Rikitea      PF -23.1203 -134.9692     73.51        68           2
# 8   Grand Gaube      MU -20.0064   57.6608     68.38        78          13
# 9    Bell Ville      AR -32.6259  -62.6887     62.67        27           9
#
#    Wind Speed Weather Description
# 0        7.67           clear sky
# 1       17.45       broken clouds
# 2       11.41     overcast clouds
# 3        8.79          few clouds
# 4       19.93     overcast clouds
# 5        1.01     overcast clouds
# 6        2.86           clear sky
# 7        7.27           clear sky
# 8        1.99          few clouds
# 9       11.70           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
